# %% [markdown]
# # data

# %%
from src.dataset import *

# %%
dataset_names = ['breast_cancer', 'heart_disease', 'diabetes']

# %%
for dn in dataset_names:
    print(f"Loading {dn} dataset...")
    dataset = Dataset(dn, cfg="config/datasets.yaml").run()
    print(f"Dataset {dn} loaded, preprocessed and saved successfully.\n")
# Out:
# Loading breast_cancer dataset...
# Dataset breast_cancer loaded, preprocessed and saved successfully.
#
# Loading heart_disease dataset...
# Dataset heart_disease loaded, preprocessed and saved successfully.
#
# Loading diabetes dataset...
# Dataset diabetes loaded, preprocessed and saved successfully.

# %% [markdown]
# # models

# %%
from src.models import *

# %%
logreg_diabetes = Model("logistic_regression", cfg="config/models.yaml").run(dataset_name="diabetes")
logreg_heart_disease = Model("logistic_regression", cfg="config/models.yaml").run(dataset_name="heart_disease")
logreg_breast_cancer = Model("logistic_regression", cfg="config/models.yaml").run(dataset_name="breast_cancer")

# %%
randfor_diabetes = Model("random_forest", cfg="config/models.yaml").run(dataset_name="diabetes")
randfor_heart_disease = Model("random_forest", cfg="config/models.yaml").run(dataset_name="heart_disease")
randfor_breast_cancer = Model("random_forest", cfg="config/models.yaml").run(dataset_name="breast_cancer")

# %%
xgboost_diabetes = Model("xgboost", cfg="config/models.yaml").run(dataset_name="diabetes")
xgboost_heart_disease = Model("xgboost", cfg="config/models.yaml").run(dataset_name="heart_disease")
xgboost_breast_cancer = Model("xgboost", cfg="config/models.yaml").run(dataset_name="breast_cancer")

# %%
svm_diabetes = Model("svm", cfg="config/models.yaml").run(dataset_name="diabetes")
svm_heart_disease = Model("svm", cfg="config/models.yaml").run(dataset_name="heart_disease")
svm_breast_cancer = Model("svm", cfg="config/models.yaml").run(dataset_name="breast_cancer")

# %%
mlp_diabetes = Model("mlp", cfg="config/models.yaml").run(dataset_name="diabetes")
mlp_heart_disease = Model("mlp", cfg="config/models.yaml").run(dataset_name="heart_disease")
mlp_breast_cancer = Model("mlp", cfg="config/models.yaml").run(dataset_name="breast_cancer")
# Out:
# c:\00_work\projects\syn-vs-enc-simplified\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\00_work\projects\syn-vs-enc-simplified\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ## model loading

# %%
from src.models import *

# %%
model = Model.load("models\logistic_regression__breast_cancer.joblib")

# %%
model.X_train.head()
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 546    -1.081325     -0.684076       -1.098091  -0.938523        -0.143774
# 432     1.719055      0.058258        1.723026   1.692556         1.205523
# 174    -0.984760     -0.963324       -1.008296  -0.868274        -0.600656
# 221    -0.161119     -1.254207       -0.139183  -0.266177         0.621966
# 289    -0.783110     -0.093001       -0.815526  -0.736307        -0.656877
#
#      mean_compactness  mean_concavity  mean_concave_points  mean_symmetry  \
# 546         -1.030979       -0.987817            -1.120082       0.267911
# 432          0.844459        1.563102             1.985643      -0.319891
# 174         -1.162123       -1.114873            -1.261820       0.424902
# 221          0.281600       -0.128052            -0.113729       0.549034
# 289         -1.028326       -0.813679            -0.701316       0.735232
#
#      mean_fractal_dimension  ...  worst_radius  worst_texture  \
# ...

# %% [markdown]
# # synthetic

# %%
from src.synthesizers import *

# %%
synth = Synthesizer("gaussian_copula", cfg="config/synthesizers.yaml")

# %%
synth.fit("breast_cancer")
# Out:
# c:\00_work\projects\syn-vs-enc-simplified\.venv\Lib\site-packages\sdv\single_table\base.py:134: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(

# %%
synth.save()

# %%
synth.sample()
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0       1.403071      0.786797        1.370419   1.241153         0.001894
# 1      -0.252269     -0.603581       -0.258369  -0.344301         0.420196
# 2      -1.811109     -0.927215       -1.762545  -1.454443         1.161880
# 3      -0.099067     -0.442770       -0.009693  -0.412584         0.936458
# 4       0.775502     -0.857532        0.602086   0.605009        -3.112085
# ..           ...           ...             ...        ...              ...
# 564     0.087977     -1.091737       -0.001383   0.034813        -1.032267
# 565    -0.172597     -0.172052       -0.260560  -0.145268        -1.352512
# 566    -0.907579      0.331569       -1.025397  -0.869559        -1.844061
# 567     0.593241      0.821372        0.437833   0.548526        -2.123407
# 568    -0.975743     -0.456048       -1.034892  -0.835113        -1.274420
#
# ...

# %%
synth.run("diabetes")
synth.run("breast_cancer")
synth.run("heart_disease")
# Out:
# c:\00_work\projects\syn-vs-enc-simplified\.venv\Lib\site-packages\sdv\single_table\base.py:134: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# c:\00_work\projects\syn-vs-enc-simplified\.venv\Lib\site-packages\sdv\single_table\base.py:134: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# c:\00_work\projects\syn-vs-enc-simplified\.venv\Lib\site-packages\sdv\single_table\base.py:134: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
#           age       sex        cp  trestbps      chol       fbs   restecg  \
# 0   -0.027622  0.686202  0.456119  1.303774  0.922083  0.334001  1.008767
# 1   -0.071048  0.271162  0.877985  0.671534 -0.783844  0.590052  0.573134
# ...
