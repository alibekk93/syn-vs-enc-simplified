# %%
from src.dataset import *

# %%
diabetes_dataset = Dataset("diabetes", cfg="config/datasets.yaml")
heart_disease_dataset = Dataset("heart_disease", cfg="config/datasets.yaml")
breast_cancer_dataset = Dataset("breast_cancer", cfg="config/datasets.yaml")

# %%
diabetes_raw = diabetes_dataset.load()
heart_disease_raw = heart_disease_dataset.load()
breast_cancer_raw = breast_cancer_dataset.load()

# %%
diabetes_prep = diabetes_dataset.preprocess(diabetes_raw)
heart_disease_prep = heart_disease_dataset.preprocess(heart_disease_raw)
breast_cancer_prep = breast_cancer_dataset.preprocess(breast_cancer_raw)

# %%
breast_cancer_prep.describe()
# Out:
#         mean_radius  mean_texture  mean_perimeter     mean_area  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean  -1.373633e-16  6.868164e-17   -1.248757e-16 -2.185325e-16
# std    1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        mean_smoothness  mean_compactness  mean_concavity  mean_concave_points  \
# count     5.690000e+02      5.690000e+02    5.690000e+02         5.690000e+02
# mean     -8.366672e-16      1.873136e-16    4.995028e-17        -4.995028e-17
# std       1.000880e+00      1.000880e+00    1.000880e+00         1.000880e+00
# ...

# %%
breast_cancer = Dataset("breast_cancer", cfg="config/datasets.yaml").run()
